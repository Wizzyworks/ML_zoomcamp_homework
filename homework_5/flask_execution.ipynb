# %%
from flask import Flask
import requests
from flask import jsonify

# %%
url = "http://127.0.0.1:9696/predict"
client = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}
requests.post(url, json=client).json()
# Out:
# {'lead': True, 'lead_prob': 0.5340417283801275}

# %%
pip install flask
# Out:
# Collecting flask
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\piyush sharma\appdata\local\programs\python\python313\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\piyush sharma\appdata\local\programs\python\python313\lib\site-packages (from flask) (8.1.8)
# Collecting itsdangerous>=2.2.0 (from flask)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\piyush sharma\appdata\local\programs\python\python313\lib\site-packages (from flask) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\piyush sharma\appdata\local\programs\python\python313\lib\site-packages (from flask) (3.0.2)
# Collecting werkzeug>=3.1.0 (from flask)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: colorama in c:\users\piyush sharma\appdata\local\programs\python\python313\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: werkzeug, itsdangerous, flask
#
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ---------------------------------------- 0/3 [werkzeug]
#    ------------- -------------------------- 1/3 [itsdangerous]
#    ------------- -------------------------- 1/3 [itsdangerous]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    -------------------------- ------------- 2/3 [flask]
#    ---------------------------------------- 3/3 [flask]
#
# Successfully installed flask-3.1.2 itsdangerous-2.2.0 werkzeug-3.1.3
# Note: you may need to restart the kernel to use updated packages.
